# %%
from datasets import load_dataset
ds = load_dataset("imagenet-1k")
train_ds = ds["train"]
train_ds[0]["image"]  # a PIL Image
# Out:
# C:\Users\zacha\Documents\GitHub\dl-final-sp2024\venv\Lib\site-packages\datasets\load.py:1486: FutureWarning: The repository for imagenet-1k contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/imagenet-1k
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(
# ...
# Loading dataset shards:   0%|          | 0/25 [00:00<?, ?it/s]
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=817x363>

# %%
print(ds)
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1281167
#     })
#     validation: Dataset({
#         features: ['image', 'label'],
#         num_rows: 50000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 100000
#     })
# })

# %%
train_ds[0]["label"]
# Out:
# 726
